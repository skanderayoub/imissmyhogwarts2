# %%
from bs4 import BeautifulSoup
import requests
import webbrowser
from urllib.parse import urljoin, unquote
import json
import os
import pandas as pd

df = pd.read_excel("./assets/Patronus_List.xlsx", sheet_name="Master List")

# %%
df
# Out:
#                  Patronus              First Question Set  \
# 0                Aardvark     Glow/Blade/Wind/Serve/Dance
# 1    Abraxan Winged Horse     Glow/Blade/Wind/Serve/Dance
# 2                   Adder  Shine/Thorn/Rain/Seek/Discover
# 3                  Badger  Glitter/Leaf/Sun/Protect/Dream
# 4           Bassett Hound  Glitter/Leaf/Sun/Protect/Dream
# ..                    ...                             ...
# 129             Wild Boar  Glitter/Leaf/Sun/Protect/Dream
# 130           Wild Rabbit  Shine/Thorn/Rain/Seek/Discover
# 131               Wildcat  Shine/Thorn/Rain/Seek/Discover
# 132                  Wolf  Shine/Thorn/Rain/Seek/Discover
# 133            Wood Mouse     Glow/Blade/Wind/Serve/Dance
#
#                       Second Question Set               Third Question Set  \
# 0      Make/Bright/Sweet/Warm/Bone/Smooth  Escape/Preen/Sense/Earth/Around
# 1      Make/Bright/Sweet/Warm/Bone/Smooth  Escape/Preen/Sense/Earth/Around
# ...
